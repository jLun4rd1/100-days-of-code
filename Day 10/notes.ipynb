# %%
# Functions with Outputs

# Syntax
def my_function():
    result = 3 * 2
    return result

my_function()

# Using output
def format_name(f_name, l_name):
    formated_f_name = f_name.title()
    formated_l_name = l_name.title()
    formated_string = f"{formated_f_name} {formated_l_name}"
    
    return formated_string
    
formated_string = format_name('joAo', 'luNaRdI')
print(formated_string)

output = len('Joao')

# Why to use return <<< to have the output of a function as an input of another function
def function_1(text):
    return text + text

def function_2(text):
    return text.title()

output = function_2(function_1("Hello"))

print(output)

# %%
# Multiple Return Values

def format_name(f_name, l_name):
    if f_name == '' or l_name == '':
        return "You didn't provide valid inputs"
    
    formated_f_name = f_name.title()
    formated_l_name = l_name.title()
    return f"{formated_f_name} {formated_l_name}"


print(format_name(input("What's your first name?"), input("What's your last name?")))

# %%
# Exercise: Leap year

# %%
# DOCSTRINGS

def format_name(f_name:str, l_name:str) -> str:
    """
    Takes a first and a last name and format them in order to return the full name in Title Case 
    """
    if f_name == '' or l_name == '':
        return "You didn't provide valid inputs"
    
    formated_f_name = f_name.title()
    formated_l_name = l_name.title()
    return f"{formated_f_name} {formated_l_name}"


print(format_name(input("What's your first name?"), input("What's your last name?")))

# %%
# Calculator Project
import art

def add(n1, n2):
    return n1 + n2

def subtract(n1, n2):
    return n1 - n2

def multiply(n1, n2):
    return n1 * n2

def divide(n1, n2):
    return n1 / n2

dictionary_of_operations = {
    '+': add,
    '-': subtract,
    '*': multiply,
    '/': divide
}

keep_going = True
more_operations = 'n'

while keep_going == True:
    print(art.logo)
    
    if more_operations == 'n':
        first_number = int(input("What's the first number?: "))
    
    for symbol in dictionary_of_operations:
        print(symbol)
        
    operation_input = input("Pick an operation: ")
    operation = dictionary_of_operations[operation_input]
    
    second_number = int(input("What's the second number?: "))

    result = operation(first_number, second_number)
    print(f'{first_number} {operation_input} {second_number} = {result}')
        
    more_operations = input(f"Type 'y' to continue calculating with {result} or type 'n' to start a new calculation. You can also type 'e' to exit.")
    
    if more_operations == 'y':
        first_number = result
    elif more_operations == 'e':
        keep_going = False

# %%
# Calculator Project - Course Solution
import art

def add(n1, n2):
    return n1 + n2

def subtract(n1, n2):
    return n1 - n2

def multiply(n1, n2):
    return n1 * n2

def divide(n1, n2):
    return n1 / n2

dictionary_of_operations = {
    '+': add,
    '-': subtract,
    '*': multiply,
    '/': divide
}

def calculator():
    keep_going = True
    more_operations = 'n'

    while keep_going == True:
        print(art.logo)
        
        if more_operations == 'n':
            first_number = int(input("What's the first number?: "))
        
        for symbol in dictionary_of_operations:
            print(symbol)
            
        operation_input = input("Pick an operation: ")
        operation = dictionary_of_operations[operation_input]
        
        second_number = int(input("What's the second number?: "))

        result = operation(first_number, second_number)
        print(f'{first_number} {operation_input} {second_number} = {result}')
            
        more_operations = input(f"Type 'y' to continue calculating with {result} or type 'n' to start a new calculation. You can also type 'e' to exit.")
        
        if more_operations == 'y':
            first_number = result
        elif more_operations == 'e':
            keep_going = False
        else:
            print(25 * '\n')
            keep_going = False
            calculator() # <<< Calling a function inside itself is called recursion in Programming
            
calculator()
# Out:
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# | |___|___|___| |___| | | |              | || |              | || |              | || |              | |
# | | . | 0 | = | | / | | | '--------------' || '--------------' || '--------------' || '--------------' |
# | |___|___|___| |___| |  '----------------'  '----------------'  '----------------'  '----------------'
# |_____________________|
#
# +
# -
# *
# /
# 10 + 10 = 20
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# | |___|___|___| |___| | | |              | || |              | || |              | || |              | |
# | | . | 0 | = | | / | | | '--------------' || '--------------' || '--------------' || '--------------' |
# | |___|___|___| |___| |  '----------------'  '----------------'  '----------------'  '----------------'
# |_____________________|
#
# +
# -
# *
# /
# 10 / 5 = 2.0
#
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# | |___|___|___| |___| | | |              | || |              | || |              | || |              | |
# | | . | 0 | = | | / | | | '--------------' || '--------------' || '--------------' || '--------------' |
# | |___|___|___| |___| |  '----------------'  '----------------'  '----------------'  '----------------'
# |_____________________|
#
# +
# -
# *
# /
# 2.0 * 2 = 4.0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# | |___|___|___| |___| | | |              | || |              | || |              | || |              | |
# | | . | 0 | = | | / | | | '--------------' || '--------------' || '--------------' || '--------------' |
# | |___|___|___| |___| |  '----------------'  '----------------'  '----------------'  '----------------'
# |_____________________|
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 55
#      52             keep_going = False
#      53             calculator() # <<< Calling a function inside itself is called recursion in Programming
# ---> 55 calculator()
#
# Cell In[30], line 53, in calculator()
#      51 print(25 * '\n')
#      52 keep_going = False
# ---> 53 calculator()
#
# Cell In[30], line 53, in calculator()
#      51 print(25 * '\n')
#      52 keep_going = False
# ---> 53 calculator()
#
# Cell In[30], line 31, in calculator()
#      28 print(art.logo)
#      30 if more_operations == 'n':
# ---> 31     first_number = int(input("What's the first number?: "))
#      33 for symbol in dictionary_of_operations:
#      34     print(symbol)
#
# ValueError: invalid literal for int() with base 10: ''
